# %% [markdown]
# # Proyecto CC5206
#
# Mineria de datos sobre datasets del banco mundial. Eliminar ultimas filas del excel

# %% [markdown]
# # Importar librerias y dataset

# %%
import numpy as np
import pandas as pd
import pdb

d_2016 = pd.read_excel('d_2016.xlsx', keep_default_na=False, na_values='')

d_2016.head()
# Out:
#           Country Name Country Code  \
# 0          Afghanistan          AFG
# 1              Albania          ALB
# 2              Algeria          DZA
# 5               Angola          AGO
# 6  Antigua and Barbuda          ATG
#
#    Adults (ages 15+) and children (ages 0-14) newly infected with HIV  \
# 0                                             1000.0
# 1                                              500.0
# 2                                             1000.0
# 5                                            25000.0
# 6                                                NaN
#
#    Adults (ages 15+) newly infected with HIV  \
# 0                                     1000.0
# 1                                      500.0
# 2                                     1000.0
# 5                                    21000.0
# 6                                        NaN
#
#    Age dependency ratio (% of working-age population)  \
# 0                                          86.570932
# 1                                          44.001540
# 2                                          53.907887
# 5                                          97.274212
# 6                                          44.818337
#
#    Age dependency ratio, old (% of working-age population)  \
# 0                                           4.741808
# 1                                          18.481017
# 2                                           9.266538
# 5                                           4.634846
# 6                                           9.743678
#
#    Age dependency ratio, young (% of working-age population)  \
# 0                                          81.829125
# 1                                          25.520523
# 2                                          44.641349
# 5                                          92.639366
# 6                                          35.074659
#
#    Agriculture value added per worker (constant 2010 US$)  \
# 0                                         632.952294
# 1                                        4253.642793
# 2                                        6221.586742
# 5                                                NaN
# 6                                        2813.977267
#
#    Agriculture, value added (% of GDP)  \
# 0                            21.910295
# 1                            22.955314
# 2                            12.949289
# 5                                  NaN
# 6                             1.926954
#
#    Agriculture, value added (annual % growth)  \
# 0                                    5.971751
# 1                                    0.460000
# 2                                    2.100000
# 5                                         NaN
# 6                                    2.943043
#
#                              ...                             \
# 0                            ...
# 1                            ...
# 2                            ...
# 5                            ...
# 6                            ...
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                              7.722
# 1                                             16.469
# 2                                              9.202
# 5                                              6.186
# 6                                                NaN
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                              8.540
# 1                                             16.333
# 2                                             11.222
# 5                                              6.579
# 6                                                NaN
#
#    Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# 0                                          23.617001
# 1                                          35.692001
# 2                                          44.348999
# 5                                          11.901000
# 6                                                NaN
#
#    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# 0                                          17.028999
# 1                                          36.841999
# 2                                          22.641001
# 5                                          10.531000
# 6                                                NaN
#
#    Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  \
# 0                                          18.326000
# 1                                          36.422001
# 2                                          26.554001
# 5                                          11.159000
# 6                                                NaN
#
#    Urban population  Urban population (% of total)  \
# 0         9402875.0                         27.132
# 1         1678953.0                         58.376
# 2        28953739.0                         71.304
# 5        12913906.0                         44.819
# 6           23618.0                         23.393
#
#    Urban population growth (annual %)  Use of IMF credit (DOD, current US$)  \
# 0                            4.282960                          2.769840e+08
# 1                            1.514007                          3.870840e+08
# 2                            2.637964                          1.610756e+09
# 5                            5.098251                          3.958810e+08
# 6                           -0.578390                                   NaN
#
#    Women's share of population ages 15+ living with HIV (%)
# 0                                          28.627356
# 1                                          29.800597
# 2                                          46.194624
# 5                                          59.712696
# 6                                                NaN
#
# [5 rows x 559 columns]

# %% [markdown]
# # Eliminar Outliers

# %%
#'''
outliers1 = [u'High income', u'High income: OECD', u'OECD members', u'World']
outliers2 = [u'East Asia & Pacific',u'East Asia & Pacific (excluding high income)',
             u'Euro area',u'Europe & Central Asia',u'European Union',u'Low & middle income',
             u'Middle income',u'North America',u'Upper middle income']

outliers3 = [u'Arab World', u'Sub-Saharan Africa',
             u'Sub-Saharan Africa (excluding high income)', u'Middle East & North Africa',
             u'Middle East & North Africa (excluding high income)', 
             u'Latin America & Caribbean',u'Latin America & Caribbean (excluding high income)',
             u'Least developed countries: UN classification', 
             u'Heavily indebted poor countries (HIPC)',u'High income',u'High income: nonOECD',
             u'High income: OECD', u'Euro area',u'Europe & Central Asia',
             u'Europe & Central Asia (excluding high income)',u'European Union',
             u'East Asia & Pacific',u'East Asia & Pacific (excluding high income)',
             u'Lower middle income',u'South Asia']

outliers4 = [u'IDA & IBRD total', u'IDA blend', u'IDA only', u'IDA total',
            u'East Asia & Pacific (IDA & IBRD countries)',u'Europe & Central Asia (IDA & IBRD countries)',
            u'Fragile and conflict affected situations',u'IBRD only',u'Late-demographic dividend',
            u'Latin America & the Caribbean (IDA & IBRD countries)',
            u'Middle East & North Africa (IDA & IBRD countries)',u'Not classified',
            u'Other small states',u'Post-demographic dividend',u'Pre-demographic dividend']


outliers5 = [u'Early-demographic dividend',u'Early-demographic dividend',u'Central Europe and the Baltics',
            u'South Asia (IDA & IBRD)',u'Sub-Saharan Africa (IDA & IBRD countries)',
            u'Sub-Saharan Africa (IDA & IBRD countries)', u'South Asia (IDA & IBRD)']

for out in outliers1:
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers2:
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers3:
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers4:
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers5:
    d_2016 = d_2016[d_2016['Country Name'] != out]
#paises = xdata['Country Name'].values.tolist()
paises = d_2016['Country Name'].values.tolist()
#xdata.head()

# %% [markdown]
# # Normalización

# %%
d_2016_n = d_2016
for k in range(2,len(d_2016.keys())):
    
    llave = d_2016.keys()[k]
    valores = d_2016[llave] 
    xvals = valores.tolist()
    #Normalización
    xmax = np.nanmax(valores)[0]
    xmin = np.nanmin(valores)[0]
    norm = xmax - xmin
    #pdb.set_trace()
    if (not np.isnan(xmax)) and norm!=0:
            d_2016_n[llave] = (d_2016[llave]-xmin)/norm
    

d_2016_n.head()
# Out:
#           Country Name Country Code  \
# 0          Afghanistan          AFG
# 1              Albania          ALB
# 2              Algeria          DZA
# 5               Angola          AGO
# 6  Antigua and Barbuda          ATG
#
#    Adults (ages 15+) and children (ages 0-14) newly infected with HIV  \
# 0                                           0.003335
# 1                                           0.001482
# 2                                           0.003335
# 5                                           0.092256
# 6                                                NaN
#
#    Adults (ages 15+) newly infected with HIV  \
# 0                                   0.003463
# 1                                   0.001539
# 2                                   0.003463
# 5                                   0.080416
# 6                                        NaN
#
#    Age dependency ratio (% of working-age population)  \
# 0                                           0.732318
# 1                                           0.280272
# 2                                           0.385468
# 5                                           0.845976
# 6                                           0.288945
#
#    Age dependency ratio, old (% of working-age population)  \
# 0                                           0.100820
# 1                                           0.500389
# 2                                           0.232410
# 5                                           0.097710
# 6                                           0.246287
#
#    Age dependency ratio, young (% of working-age population)  \
# 0                                           0.730290
# 1                                           0.111686
# 2                                           0.321747
# 5                                           0.849050
# 6                                           0.216648
#
#    Agriculture value added per worker (constant 2010 US$)  \
# 0                                           0.001734
# 1                                           0.016314
# 2                                           0.024239
# 5                                                NaN
# 6                                           0.010517
#
#    Agriculture, value added (% of GDP)  \
# 0                             0.356325
# 1                             0.373348
# 2                             0.210349
# 5                                  NaN
# 6                             0.030794
#
#    Agriculture, value added (annual % growth)  \
# 0                                    0.466883
# 1                                    0.412090
# 2                                    0.428394
# 5                                         NaN
# 6                                    0.436774
#
#                              ...                             \
# 0                            ...
# 1                            ...
# 2                            ...
# 5                            ...
# 6                            ...
#
#    Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                           0.252891
# 1                                           0.542767
# 2                                           0.301939
# 5                                           0.201988
# 6                                                NaN
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                           0.266451
# 1                                           0.516234
# 2                                           0.352415
# 5                                           0.203596
# 6                                                NaN
#
#    Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)  \
# 0                                           0.354819
# 1                                           0.538645
# 2                                           0.670437
# 5                                           0.176458
# 6                                                NaN
#
#    Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)  \
# 0                                           0.244433
# 1                                           0.534691
# 2                                           0.326648
# 5                                           0.149238
# 6                                                NaN
#
#    Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  \
# 0                                           0.266284
# 1                                           0.535694
# 2                                           0.388781
# 5                                           0.159583
# 6                                                NaN
#
#    Urban population  Urban population (% of total)  \
# 0          0.011982                       0.204914
# 1          0.002115                       0.545828
# 2          0.036959                       0.686889
# 5          0.016468                       0.397903
# 6          0.000000                       0.164117
#
#    Urban population growth (annual %)  Use of IMF credit (DOD, current US$)  \
# 0                            0.788032                              0.020581
# 1                            0.384399                              0.029006
# 2                            0.548240                              0.122650
# 5                            0.906878                              0.029679
# 6                            0.079389                                   NaN
#
#    Women's share of population ages 15+ living with HIV (%)
# 0                                           0.341325
# 1                                           0.361426
# 2                                           0.642299
# 5                                           0.873899
# 6                                                NaN
#
# [5 rows x 559 columns]

# %% [markdown]
# # Analisis Estadistico

# %%
varianzas = []
promedios = []
maximos = []
minimos = []
desv = []
for k in range(2,len(d_2016_n.keys())):
    
    llave = d_2016_n.keys()[k]
    valores = d_2016_n[llave] 
    count = 0
    
    #Normalización
    xmax = np.nanmax(valores)
    xmean = np.nanmean(valores)
    xmin = np.nanmin(valores)
    xstd = np.nanstd(valores)
    xvar = np.nanvar(valores)
    if np.isnan(xvar):
        print llave
    
    promedios.append(xmean)
    minimos.append(xmin)
    maximos.append(xmax)
    desv.append(xstd)
    varianzas.append(xvar)
    
sort = np.sort(varianzas)

most = -1   

print "Estadisticas con mayor varianza:"
#pdb.set_trace()
for i in range(10):
    value = sort[most]
    j = np.argwhere(varianzas == sort[most])+2
    features = d_2016_n.keys()
    print str(i+1)+' '+str(features[j])+' ('+str(sort[most]) +')'
    most-=1
# Out:
# Estadisticas con mayor varianza:
# 1 Index([[u'Depth of credit information index (0=low to 8=high)']], dtype='object') (0.152138985105)
# 2 Index([[u'Private credit bureau coverage (% of adults)']], dtype='object') (0.134096238441)
# 3 Index([[u'Concessional debt (% of total external debt)']], dtype='object') (0.100182084508)
# 4 Index([[u'Fixed broadband subscriptions (per 100 people)']], dtype='object') (0.0881075297842)
# 5 Index([[u'Population ages 55-59, female (% of female population)']], dtype='object') (0.0865580624523)
# 6 Index([[u'Population ages 60-64, male (% of male population)']], dtype='object') (0.0841854183587)
# 7 Index([[u'Ease of doing business index (1=most business-friendly regulations)']], dtype='object') (0.0838358184984)
# 8 Index([[u'Population ages 15-19, female (% of female population)']], dtype='object') (0.0810447228496)
# 9 Index([[u'Individuals using the Internet (% of population)']], dtype='object') (0.0809825520449)
# 10 Index([[u'Population ages 65 and above, female (% of total)']], dtype='object') (0.0796265478638)

# %% [markdown]
# # Graficos

# %% [markdown]
# ## Histogramas

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

x = []
for nonan in xdata['Population ages 0-14, total']:
#for nonan in xdata['Self-employed, male (% of males employed)']:
    if not np.isnan(nonan):
        x.append(nonan)

ax1.hist(x, 5, facecolor='green', alpha=0.75)

ax1.set_xlabel('Population ages 0-14')
ax1.set_ylabel('Total')
#ax1.title('Histograma')

#plt.add_subplot(212, facecolor='r')
x =[]
for nonan in xdata['Self-employed, male (% of males employed)']:
    if not np.isnan(nonan):
        x.append(nonan)

ax2.hist(x, 5, facecolor='blue', alpha=0.75)

ax2.set_xlabel('Self-employed, male')
ax2.set_ylabel('% of males employed')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e9afdfa36f5e> in <module>()
#       6
#       7 x = []
# ----> 8 for nonan in xdata['Population ages 0-14, total']:
#       9 #for nonan in xdata['Self-employed, male (% of males employed)']:
#      10     if not np.isnan(nonan):
#
# NameError: name 'xdata' is not defined

# %% [markdown]
# ## Codo

# %%
np_df = d_2016_n.as_matrix()
test = np_df[:,2:]
for row in range(test.shape[0]):
    for column in range(test.shape[1]):
        val = test[row][column]
        #print val
        if np.isnan(val):
            test[row][column]= promedios[column] 
        else:
            #test[row][column]= val/maximos[column] 
            pass

xdf = pd.DataFrame(test)

vectors = []
tot = test#.T
for i in range(len(tot[:,0])):
    vectors.append(tot[i])
    

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets
from sklearn import metrics
from scipy.spatial.distance import cdist

X = tot

# k means determine k
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
 
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# # TSNE

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
X = vectors
X_embedded = TSNE(n_components=2,n_iter=100000000).fit_transform(X)
X_embedded.shape
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c="r", cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# # PCA

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]

X = tot
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X = pca.transform(X)


plt.scatter(X[:, 0], X[:, 1], c="r", cmap=plt.cm.spectral,
           edgecolor='k')


plt.show()

# %% [markdown]
# # clustering

# %%
from sklearn.cluster import KMeans
from sklearn import datasets

X = tot

kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
labels = kmeans.labels_

centroids = kmeans.cluster_centers_

# %% [markdown]
# # tSNE

# %%
r = []
r_l = []
g = []
g_l = []
b = [] 
b_l = []
y = []
y_l = []
c=[]
c_l=[]
m=[]
m_l=[]

r_embedded = TSNE(n_components=2,n_iter=100000000).fit_transform(X)
r_embedded.shape
for k in range(len(labels)):
    if labels[k]==0:
        r.append(X_embedded[k])
        r_l.append(paises[k])
    elif labels[k]==1:
        g.append(X_embedded[k])
        g_l.append(paises[k])
    elif labels[k]==2:
        b.append(X_embedded[k])
        b_l.append(paises[k])
    elif labels[k]==3:
        y.append(X_embedded[k])
        y_l.append(paises[k])
    elif labels[k]==4:
        c.append(X_embedded[k])
        c_l.append(paises[k])
    elif labels[k]==5:
        m.append(X_embedded[k])
        m_l.append(paises[k])
plt.scatter([item[0] for item in r], [item[1] for item in r], c="r", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in g], [item[1] for item in g], c="g", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in b], [item[1] for item in b], c="b", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in y], [item[1] for item in y], c="y", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in c], [item[1] for item in c], c="c", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in m], [item[1] for item in m], c="m", cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# # PCA

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets


X = tot
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X = pca.transform(X)

r = []
r_l = []
g = []
g_l = []
b = [] 
b_l = []
y = []
y_l = []
c = []
c_l = []

for k in range(len(labels)):
    if labels[k]==0:
        r.append(X[k])
        r_l.append(paises[k])
    elif labels[k]==1:
        g.append(X[k])
        g_l.append(paises[k])
    elif labels[k]==2:
        b.append(X[k])
        b_l.append(paises[k])
    elif labels[k]==3:
        y.append(X[k])
        y_l.append(paises[k])
    elif labels[k]==4:
        c.append(X[k])
        c_l.append(paises[k])
        
plt.scatter([item[0] for item in r], [item[1] for item in r], c="r", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in g], [item[1] for item in g], c="g", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in b], [item[1] for item in b], c="b", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in y], [item[1] for item in y], c="y", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in c], [item[1] for item in c], c="c", cmap=plt.cm.Spectral)
plt.show()

# %%
r_l
# Out:
# [u'Albania',
#  u'Algeria',
#  u'Antigua and Barbuda',
#  u'Armenia',
#  u'Azerbaijan',
#  u'Bahamas, The',
#  u'Bangladesh',
#  u'Belize',
#  u'Bhutan',
#  u'Bolivia',
#  u'Botswana',
#  u'Brunei Darussalam',
#  u'Cabo Verde',
#  u'Caribbean small states',
#  u'Chile',
#  u'Colombia',
#  u'Costa Rica',
#  u'Dominica',
#  u'Dominican Republic',
#  u'Ecuador',
#  u'Egypt, Arab Rep.',
#  u'El Salvador',
#  u'Fiji',
#  u'Grenada',
#  u'Guatemala',
#  u'Guyana',
#  u'Honduras',
#  u'Iran, Islamic Rep.',
#  u'Jamaica',
#  u'Jordan',
#  u'Kazakhstan',
#  u'Kosovo',
#  u'Kyrgyz Republic',
#  u'Lebanon',
#  u'Malaysia',
#  u'Maldives',
#  u'Mauritius',
#  u'Moldova',
#  u'Mongolia',
#  u'Morocco',
#  u'Nicaragua',
#  u'Panama',
#  u'Paraguay',
#  u'Peru',
#  u'Philippines',
#  u'Qatar',
#  u'Samoa',
#  u'Saudi Arabia',
#  u'South Africa',
#  u'Sri Lanka',
#  u'St. Lucia',
#  u'St. Vincent and the Grenadines',
#  u'Suriname',
#  u'Syrian Arab Republic',
#  u'Tonga',
#  u'Trinidad and Tobago',
#  u'Tunisia',
#  u'Turkmenistan',
#  u'United Arab Emirates',
#  u'Uzbekistan',
#  u'Venezuela, RB',
#  u'Vietnam',
#  u'West Bank and Gaza']

# %%
g_l
# Out:
# [u'Australia',
#  u'Austria',
#  u'Belarus',
#  u'Belgium',
#  u'Bosnia and Herzegovina',
#  u'Bulgaria',
#  u'Canada',
#  u'Croatia',
#  u'Cyprus',
#  u'Czech Republic',
#  u'Denmark',
#  u'Estonia',
#  u'Finland',
#  u'France',
#  u'Georgia',
#  u'Germany',
#  u'Greece',
#  u'Hong Kong SAR, China',
#  u'Hungary',
#  u'Iceland',
#  u'Ireland',
#  u'Israel',
#  u'Italy',
#  u'Korea, Rep.',
#  u'Latvia',
#  u'Lithuania',
#  u'Luxembourg',
#  u'Macedonia, FYR',
#  u'Malta',
#  u'Montenegro',
#  u'Netherlands',
#  u'Norway',
#  u'Poland',
#  u'Portugal',
#  u'Romania',
#  u'Serbia',
#  u'Singapore',
#  u'Slovak Republic',
#  u'Slovenia',
#  u'Spain',
#  u'Sweden',
#  u'Thailand',
#  u'Ukraine',
#  u'United Kingdom',
#  u'Uruguay']

# %%
b_l
# Out:
# [u'Argentina',
#  u'Brazil',
#  u'China',
#  u'India',
#  u'Indonesia',
#  u'Mexico',
#  u'Russian Federation',
#  u'Turkey']

# %%
y_l
# Out:
# [u'Afghanistan',
#  u'Angola',
#  u'Benin',
#  u'Burkina Faso',
#  u'Burundi',
#  u'Cambodia',
#  u'Cameroon',
#  u'Central African Republic',
#  u'Chad',
#  u'Comoros',
#  u'Congo, Dem. Rep.',
#  u'Congo, Rep.',
#  u"Cote d'Ivoire",
#  u'Djibouti',
#  u'Equatorial Guinea',
#  u'Eritrea',
#  u'Ethiopia',
#  u'Gabon',
#  u'Gambia, The',
#  u'Ghana',
#  u'Guinea',
#  u'Guinea-Bissau',
#  u'Haiti',
#  u'Iraq',
#  u'Kenya',
#  u'Lao PDR',
#  u'Lesotho',
#  u'Liberia',
#  u'Low income',
#  u'Madagascar',
#  u'Malawi',
#  u'Mali',
#  u'Mauritania',
#  u'Mozambique',
#  u'Myanmar',
#  u'Nepal',
#  u'Niger',
#  u'Nigeria',
#  u'Pakistan',
#  u'Papua New Guinea',
#  u'Rwanda',
#  u'Sao Tome and Principe',
#  u'Senegal',
#  u'Sierra Leone',
#  u'Solomon Islands',
#  u'Somalia',
#  u'Sudan',
#  u'Swaziland',
#  u'Tajikistan',
#  u'Tanzania',
#  u'Togo',
#  u'Uganda',
#  u'Vanuatu',
#  u'Yemen, Rep.',
#  u'Zambia',
#  u'Zimbabwe']

# %%
c_l
# Out:
# []

# %%
m_l
