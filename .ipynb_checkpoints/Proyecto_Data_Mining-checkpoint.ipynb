# %% [markdown]
# # Proyecto CC5206
#
# Mineria de datos sobre datasets del banco mundial. Eliminar ultimas filas del excel

# %% [markdown]
# # Importar librerias y dataset

# %%
import numpy as np
import pandas as pd
import pdb

data = pd.read_excel('jobs.xlsx')
dev_2016 = pd.read_excel('development_2016.xlsx')

dev_2016.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#    2016 [YR2016]
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# # Ajustar Formato de la Tabla

# %%
#Eliminar Columnas que no serán utilizadas
data.__delitem__('Series Code')
dev_2016.__delitem__('Series Code')

# %% [markdown]
# ## Development

# %%
#El metodo np.unique ordena las listas 
#es necesario devolver la lista a su orden original
#===================================================
paises_d = np.array(dev_2016['Country Name'])
indexes_d = np.unique(paises_d, return_index=True)[1]
paises_d = [paises_d[index] for index in sorted(indexes_d)]

features_d = np.array(dev_2016['Series Name'])
indexes_d = np.unique(features_d, return_index=True)[1]
features_d = [features_d[index] for index in sorted(indexes_d)]

codes_d = np.array(dev_2016['Country Code'])
indexes_d = np.unique(codes_d, return_index=True)[1]
codes_d = [codes_d[index] for index in sorted(indexes_d)]

#====================================================

columns_d = [('Country Name',paises_d),('Country Code',codes_d)]
empty = 0
notempty = 0
for c_feature in features_d:
    #print c_feature
    #values = []
    #values.append(c_feature)
    vals = dev_2016[dev_2016['Series Name'] == c_feature]['2016 [YR2016]']
    xvals = vals.tolist()
    #values = values+xvals
    if np.negative(np.isnan(np.array(xvals))).any():
    #not np.isnan(d_2016[c_feature].all()):
        columns_d.append((c_feature,xvals))
        notempty+=1
    else:
        empty+=1

      
d_2016 = pd.DataFrame.from_items(columns_d)
d_2016.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:28: DeprecationWarning: numpy boolean negative, the `-` operator, is deprecated, use the `~` operator or the logical_not function instead.
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND
#
#    Adjusted net enrollment rate, primary (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net enrollment rate, primary, female (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net enrollment rate, primary, male (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school (% of lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school, female (% of female lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school, male (% of male lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adults (ages 15+) and children (ages 0-14) newly infected with HIV  \
# 0                                             1000.0
# 1                                              500.0
# 2                                             1000.0
# 3                                                NaN
# 4                                                NaN
#
#    Adults (ages 15+) newly infected with HIV  \
# 0                                     1000.0
# 1                                      500.0
# 2                                     1000.0
# 3                                        NaN
# 4                                        NaN
#
#                              ...                             \
# 0                            ...
# 1                            ...
# 2                            ...
# 3                            ...
# 4                            ...
#
#    Wholesale price index (2010 = 100)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife (any of five reasons) (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she argues with him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she burns the food (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she neglects the children (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she refuses sex with him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women's share of population ages 15+ living with HIV (%)
# 0                                          28.627356
# 1                                          29.800597
# 2                                          46.194624
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 1027 columns]

# %% [markdown]
# ## Jobs

# %%
#El metodo np.unique ordena las listas 
#es necesario devolver la lista a su orden original
#===================================================
paises = np.array(data['Country Name'])
indexes = np.unique(paises, return_index=True)[1]
paises = [paises[index] for index in sorted(indexes)]

caracteristicas = np.array(data['Series Name'])
indexes = np.unique(caracteristicas, return_index=True)[1]
caracteristicas = [caracteristicas[index] for index in sorted(indexes)]

codigos = np.array(data['Country Code'])
indexes = np.unique(codigos, return_index=True)[1]
codigos = [codigos[index] for index in sorted(indexes)]

#====================================================

columnas = [('Country Name',paises),('Country Code',codigos)]

for i in range(len(caracteristicas)):
    car = caracteristicas[i]
    count = 0
    nans = 0
    values = []
    while count<len(paises):
        ind = i+count*len(caracteristicas)
        val = data['Most Recent Value [YR20111]'][ind]
        if '..' == val:
            xval = np.nan
            nans += 1
        else:
            xval = float(val)
        values.append(xval)
        count+=1
    if nans != count:
        columnas.append((car,values))
      
xdata = pd.DataFrame.from_items(columnas)
xdata.head()
# Out:
#      Country Name Country Code  Access to electricity (% of population)  \
# 0     Afghanistan          AFG                                 43.00000
# 1         Albania          ALB                                100.00000
# 2         Algeria          DZA                                100.00000
# 3  American Samoa          ASM                                 59.32891
# 4         Andorra          AND                                100.00000
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                            76.7336
# 1                                            21.4896
# 2                                            10.7914
# 3                                                NaN
# 4                                                NaN
#
#    Age dependency ratio (% of working-age population)  \
# 0                                          89.773777
# 1                                          44.912136
# 2                                          51.536631
# 3                                                NaN
# 4                                                NaN
#
#    Agriculture value added per worker (constant 2005 US$)  \
# 0                                         395.782545
# 1                                        3914.815249
# 2                                        3718.553866
# 3                                                NaN
# 4                                        4149.463596
#
#    Agriculture, value added (% of GDP)  \
# 0                            23.966824
# 1                            22.671257
# 2                            10.011399
# 3                                  NaN
# 4                             0.523888
#
#    Agriculture, value added (annual % growth)  \
# 0                                        1.90
# 1                                        1.98
# 2                                       10.30
# 3                                         NaN
# 4                                         NaN
#
#    Agriculture, value added (constant 2005 US$)  \
# 0                                  2.689738e+09
# 1                                  2.317571e+09
# 2                                  1.185475e+10
# 3                                           NaN
# 4                                  1.244839e+07
#
#    Air transport, registered carrier departures worldwide  \
# 0                                       25389.376787
# 1                                        1994.750856
# 2                                       59588.200311
# 3                                        9138.074929
# 4                                                NaN
#
#                                ...                               \
# 0                              ...
# 1                              ...
# 2                              ...
# 3                              ...
# 4                              ...
#
#    Union members (% of total paid employees)  Urban population  \
# 0                                        NaN         8312341.0
# 1                                        NaN         1632744.0
# 2                                        NaN        27304259.0
# 3                                        NaN           48374.0
# 4                                        NaN           62329.0
#
#    Urban population (% of total)  Vehicles (per km of road)  \
# 0                         26.282                  41.579259
# 1                         56.409                  12.454833
# 2                         70.129                  35.604091
# 3                         87.264                        NaN
# 4                         85.633                        NaN
#
#    Vulnerable employment, female (% of female employment)  \
# 0                                                NaN
# 1                                               62.0
# 2                                               24.4
# 3                                                NaN
# 4                                                NaN
#
#    Vulnerable employment, male (% of male employment)  \
# 0                                                NaN
# 1                                          54.799999
# 2                                          27.500000
# 3                                                NaN
# 4                                                NaN
#
#    Wage and salaried workers, female (% of females employed)  \
# 0                                                NaN
# 1                                          36.900002
# 2                                          73.699997
# 3                                          98.500000
# 4                                                NaN
#
#    Wage and salaried workers, total (% of total employed)  \
# 0                                                NaN
# 1                                          40.200001
# 2                                          69.000000
# 3                                          96.900002
# 4                                                NaN
#
#    Wage and salary workers, male (% of males employed)  \
# 0                                                NaN
# 1                                          42.900002
# 2                                          67.900002
# 3                                          97.000000
# 4                                                NaN
#
#    Weeks of severance pay for redundancy of experienced workers
# 0                                          26.000000
# 1                                          42.857143
# 2                                          13.000000
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 187 columns]

# %% [markdown]
# # Eliminar Outliers

# %%
#'''
outliers1 = [u'High income', u'High income: OECD', u'OECD members', u'World']
outliers2 = [u'East Asia & Pacific',u'East Asia & Pacific (excluding high income)',
 u'Euro area',u'Europe & Central Asia',u'European Union',u'Low & middle income',
 u'Middle income',u'North America',u'Upper middle income']

outliers3 = [u'Arab World', u'Sub-Saharan Africa',
             u'Sub-Saharan Africa (excluding high income)', u'Middle East & North Africa',
             u'Middle East & North Africa (excluding high income)', 
             u'Latin America & Caribbean',u'Latin America & Caribbean (excluding high income)',
             u'Least developed countries: UN classification', 
             u'Heavily indebted poor countries (HIPC)',u'High income',u'High income: nonOECD',
             u'High income: OECD', u'Euro area',u'Europe & Central Asia',
             u'Europe & Central Asia (excluding high income)',u'European Union',
             u'East Asia & Pacific',u'East Asia & Pacific (excluding high income)',
             u'Lower middle income',u'South Asia']

outliers4 = [u'IDA & IBRD total', u'IDA blend', u'IDA only', u'IDA total']

for out in outliers1:
    xdata = xdata[xdata['Country Name'] != out]
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers2:
    xdata = xdata[xdata['Country Name'] != out]
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers3:
    xdata = xdata[xdata['Country Name'] != out]
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers4:
    xdata = xdata[xdata['Country Name'] != out]
    d_2016 = d_2016[d_2016['Country Name'] != out]
#paises = xdata['Country Name'].values.tolist()
paises = d_2016['Country Name'].values.tolist()
#xdata.head()

# %% [markdown]
# # Normalización

# %% [markdown]
# ## Development

# %%
d_2016_n = d_2016
for k in range(2,len(d_2016.keys())):
    
    llave = d_2016.keys()[k]
    valores = d_2016[llave] 
    
    #Normalización
    xmax = np.nanmax(valores)[0]
    #pdb.set_trace()
    if not np.isnan(xmax) and xmax>1.0:
            d_2016_n[llave] = d_2016[llave]/xmax
    
d_2016_n.head()
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND
#
#    Adjusted net enrollment rate, primary (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net enrollment rate, primary, female (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net enrollment rate, primary, male (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school (% of lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school, female (% of female lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school, male (% of male lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adults (ages 15+) and children (ages 0-14) newly infected with HIV  \
# 0                                           0.003704
# 1                                           0.001852
# 2                                           0.003704
# 3                                                NaN
# 4                                                NaN
#
#    Adults (ages 15+) newly infected with HIV  \
# 0                                   0.003846
# 1                                   0.001923
# 2                                   0.003846
# 3                                        NaN
# 4                                        NaN
#
#                              ...                             \
# 0                            ...
# 1                            ...
# 2                            ...
# 3                            ...
# 4                            ...
#
#    Wholesale price index (2010 = 100)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife (any of five reasons) (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she argues with him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she burns the food (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she neglects the children (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she refuses sex with him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women's share of population ages 15+ living with HIV (%)
# 0                                           0.426809
# 1                                           0.444301
# 2                                           0.688722
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 1027 columns]

# %% [markdown]
# # Analisis Estadistico

# %% [markdown]
# ## Development

# %%
varianzas = []
promedios = []
maximos = []
minimos = []
desv = []
for k in range(2,len(d_2016_n.keys())):
    
    llave = d_2016_n.keys()[k]
    valores = d_2016_n[llave] 
    count = 0
    
    #Normalización
    xmax = np.nanmax(valores)
    xmean = np.nanmean(valores)
    xmin = np.nanmin(valores)
    xstd = np.nanstd(valores)
    xvar = np.nanvar(valores)
    
    promedios.append(xmean)
    minimos.append(xmin)
    maximos.append(xmax)
    desv.append(xstd)
    varianzas.append(xvar)
    
sort = np.sort(varianzas)
most = -1   

print "Estadisticas con mayor varianza:"
for i in range(10):
    j = np.argwhere(varianzas == sort[most])
    k = sort[most]
    print str(i+1)+' '+features_d[j]+' ('+str(sort[most]) #+')\n'
    most-=1
# Out:
# Estadisticas con mayor varianza:
# 1 Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient) (6.51129848625e+16
# 2 Gross capital formation (constant 2010 US$) (122.771880971
# 3 Government expenditure on education, total (% of GDP) (4.48173182516
# 4 Child employment in manufacturing, male (% of male economically active children ages 7-14) (3.88421350483
# 5 Gross capital formation (annual % growth) (1.72764673813
# 6 Gross capital formation (current LCU) (0.649607796601
# 7 Methane emissions in energy sector (thousand metric tons of CO2 equivalent) (0.452445830252
# 8 Net foreign assets (current LCU) (0.248435099389
# 9 Children in employment, work only, female (% of female children in employment, ages 7-14) (0.240399969084
# 10 Children out of school (% of primary school age) (0.220110046865
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:32: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future

# %% [markdown]
# ## Jobs

# %%
varianzas = []
promedios = []
maximos = []
minimos = []
desv = []
for k in range(2,len(xdata.keys())):
    
    llave = xdata.keys()[k]
    valores = xdata[llave] 
    count = 0
    
    #print llave
    xmean = np.nanmean(valores)
    xmin = np.nanmin(valores)
    xmax = np.nanmax(valores)
    xstd = np.nanstd(valores)
    xvar = np.nanvar(valores)
    
    promedios.append(xmean)
    minimos.append(xmin)
    maximos.append(xmax)
    desv.append(xstd)
    varianzas.append(xvar)
    
sort = np.sort(varianzas)
most = -1   

print "Estadisticas con mayor varianza:"
for i in range(10):
    j = np.argwhere(varianzas == sort[most])
    k = sort[most]
    pdb.set_trace()
    print str(i+1)+' '+caracteristicas[j]     #+' ('+str(sort[most])')
    most-=1

#promedios
#sort
#xdata

# %% [markdown]
# # Graficos

# %% [markdown]
# ## Histogramas

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

x = []
for nonan in xdata['Population ages 0-14, total']:
#for nonan in xdata['Self-employed, male (% of males employed)']:
    if not np.isnan(nonan):
        x.append(nonan)

ax1.hist(x, 5, facecolor='green', alpha=0.75)

ax1.set_xlabel('Population ages 0-14')
ax1.set_ylabel('Total')
#ax1.title('Histograma')

#plt.add_subplot(212, facecolor='r')
x =[]
for nonan in xdata['Self-employed, male (% of males employed)']:
    if not np.isnan(nonan):
        x.append(nonan)

ax2.hist(x, 5, facecolor='blue', alpha=0.75)

ax2.set_xlabel('Self-employed, male')
ax2.set_ylabel('% of males employed')

plt.show()

# %% [markdown]
# ## Codo

# %% [markdown]
# ## Jobs

# %%
np_df = xdata.as_matrix()
test = np_df[:,2:]
for row in range(test.shape[0]):
    for column in range(test.shape[1]):
        val = test[row][column]
        if np.isnan(val):
            test[row][column]= promedios[column] #meanx #0 #fixed.data[0]
        else:
            pass

xdf = pd.DataFrame(test)

vectors = []
tot = test#.T
for i in range(len(tot[:,0])):
    vectors.append(tot[i])

# %% [markdown]
# ## Development

# %%
np_df = d_2016_n.as_matrix()
test = np_df[:,2:]
for row in range(test.shape[0]):
    for column in range(test.shape[1]):
        val = test[row][column]
        #print val
        if np.isnan(val):
            test[row][column]= promedios[column] 
        else:
            #test[row][column]= val/maximos[column] 
            pass

xdf = pd.DataFrame(test)

vectors = []
tot = test#.T
for i in range(len(tot[:,0])):
    vectors.append(tot[i])
    
#xdf.head()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets
from sklearn import metrics
from scipy.spatial.distance import cdist

X = tot

#kmeans = KMeans(n_clusters=4)
#kmeans.fit(X)
#labels = kmeans.labels_

#centroids = kmeans.cluster_centers_

# k means determine k
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
 
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# # TSNE

# %% [markdown]
# ## Development

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
X = vectors
X_embedded = TSNE(n_components=2,n_iter=100000000).fit_transform(X)
X_embedded.shape
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c="r", cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# ## Jobs

# %%
from sklearn.manifold import TSNE
X = vectors
X_embedded = TSNE(n_components=2,n_iter=100000000).fit_transform(X)
X_embedded.shape
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c="r", cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# # PCA

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]

X = tot
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X = pca.transform(X)


plt.scatter(X[:, 0], X[:, 1], c="r", cmap=plt.cm.spectral,
           edgecolor='k')


plt.show()

# %% [markdown]
# # clustering

# %%
from sklearn.cluster import KMeans
from sklearn import datasets

X = tot

kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
labels = kmeans.labels_

centroids = kmeans.cluster_centers_

# %% [markdown]
# # tSNE

# %%
r = []
r_l = []
g = []
g_l = []
b = [] 
b_l = []
y = []
y_l = []
c=[]
c_l=[]
m=[]
m_l=[]

r_embedded = TSNE(n_components=2,n_iter=100000000).fit_transform(X)
r_embedded.shape
for k in range(len(labels)):
    if labels[k]==0:
        r.append(X_embedded[k])
        r_l.append(paises[k])
    elif labels[k]==1:
        g.append(X_embedded[k])
        g_l.append(paises[k])
    elif labels[k]==2:
        b.append(X_embedded[k])
        b_l.append(paises[k])
    elif labels[k]==3:
        y.append(X_embedded[k])
        y_l.append(paises[k])
    elif labels[k]==4:
        c.append(X_embedded[k])
        c_l.append(paises[k])
    elif labels[k]==5:
        m.append(X_embedded[k])
        m_l.append(paises[k])
plt.scatter([item[0] for item in r], [item[1] for item in r], c="r", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in g], [item[1] for item in g], c="g", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in b], [item[1] for item in b], c="b", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in y], [item[1] for item in y], c="y", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in c], [item[1] for item in c], c="c", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in m], [item[1] for item in m], c="m", cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# # PCA

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets


X = tot
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X = pca.transform(X)

r = []
r_l = []
g = []
g_l = []
b = [] 
b_l = []
y = []
y_l = []

for k in range(len(labels)):
    if labels[k]==0:
        r.append(X[k])
        r_l.append(paises[k])
    elif labels[k]==1:
        g.append(X[k])
        g_l.append(paises[k])
    elif labels[k]==2:
        b.append(X[k])
        b_l.append(paises[k])
    elif labels[k]==3:
        y.append(X[k])
        y_l.append(paises[k])
        
plt.scatter([item[0] for item in r], [item[1] for item in r], c="r", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in g], [item[1] for item in g], c="g", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in b], [item[1] for item in b], c="b", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in y], [item[1] for item in y], c="y", cmap=plt.cm.Spectral)
plt.show()

# %%
r_l
# Out:
# [u'American Samoa',
#  u'Andorra',
#  u'Antigua and Barbuda',
#  u'Aruba',
#  u'Australia',
#  u'Austria',
#  u'Bahamas, The',
#  u'Bahrain',
#  u'Barbados',
#  u'Belgium',
#  u'Bermuda',
#  u'British Virgin Islands',
#  u'Brunei Darussalam',
#  u'Cambodia',
#  u'Canada',
#  u'Caribbean small states',
#  u'Cayman Islands',
#  u'Central Europe and the Baltics',
#  u'Channel Islands',
#  u'Chile',
#  u'Croatia',
#  u'Cuba',
#  u'Curacao',
#  u'Cyprus',
#  u'Czech Republic',
#  u'Denmark',
#  u'Early-demographic dividend',
#  u'East Asia & Pacific (IDA & IBRD countries)',
#  u'Equatorial Guinea',
#  u'Estonia',
#  u'Europe & Central Asia (IDA & IBRD countries)',
#  u'Faroe Islands',
#  u'Finland',
#  u'Fragile and conflict affected situations',
#  u'France',
#  u'French Polynesia',
#  u'Germany',
#  u'Gibraltar',
#  u'Greece',
#  u'Greenland',
#  u'Guam',
#  u'Hong Kong SAR, China',
#  u'Hungary',
#  u'IBRD only',
#  u'Iceland',
#  u'Iraq',
#  u'Ireland',
#  u'Isle of Man',
#  u'Israel',
#  u'Italy',
#  u'Japan',
#  u'Kiribati',
#  u'Korea, Dem. People\u2019s Rep.',
#  u'Korea, Rep.',
#  u'Kuwait',
#  u'Kyrgyz Republic',
#  u'Late-demographic dividend',
#  u'Latin America & the Caribbean (IDA & IBRD countries)',
#  u'Latvia',
#  u'Libya',
#  u'Liechtenstein',
#  u'Lithuania',
#  u'Low income',
#  u'Luxembourg',
#  u'Macao SAR, China',
#  u'Madagascar',
#  u'Malta',
#  u'Marshall Islands',
#  u'Micronesia, Fed. Sts.',
#  u'Middle East & North Africa (IDA & IBRD countries)',
#  u'Monaco',
#  u'Namibia',
#  u'Nauru',
#  u'Netherlands',
#  u'New Caledonia',
#  u'New Zealand',
#  u'Northern Mariana Islands',
#  u'Norway',
#  u'Not classified',
#  u'Oman',
#  u'Other small states',
#  u'Pacific island small states',
#  u'Palau',
#  u'Poland',
#  u'Portugal',
#  u'Post-demographic dividend',
#  u'Pre-demographic dividend',
#  u'Puerto Rico',
#  u'Qatar',
#  u'San Marino',
#  u'Saudi Arabia',
#  u'Seychelles',
#  u'Singapore',
#  u'Sint Maarten (Dutch part)',
#  u'Slovak Republic',
#  u'Slovenia',
#  u'Small states',
#  u'South Asia (IDA & IBRD)',
#  u'South Sudan',
#  u'Spain',
#  u'St. Kitts and Nevis',
#  u'St. Martin (French part)',
#  u'Sub-Saharan Africa (IDA & IBRD countries)',
#  u'Suriname',
#  u'Sweden',
#  u'Switzerland',
#  u'Timor-Leste',
#  u'Trinidad and Tobago',
#  u'Turks and Caicos Islands',
#  u'Tuvalu',
#  u'United Arab Emirates',
#  u'United Kingdom',
#  u'United States',
#  u'Uruguay',
#  u'Virgin Islands (U.S.)',
#  u'West Bank and Gaza']

# %%
g_l
# Out:
# [u'Mexico']

# %%
b_l
# Out:
# [u'Cameroon', u'Peru']

# %%
y_l
# Out:
# [u'Afghanistan',
#  u'Albania',
#  u'Algeria',
#  u'Angola',
#  u'Argentina',
#  u'Armenia',
#  u'Azerbaijan',
#  u'Bangladesh',
#  u'Belarus',
#  u'Belize',
#  u'Benin',
#  u'Bhutan',
#  u'Bolivia',
#  u'Bosnia and Herzegovina',
#  u'Botswana',
#  u'Brazil',
#  u'Bulgaria',
#  u'Burkina Faso',
#  u'Burundi',
#  u'Cabo Verde',
#  u'Central African Republic',
#  u'Chad',
#  u'China',
#  u'Colombia',
#  u'Comoros',
#  u'Congo, Dem. Rep.',
#  u'Congo, Rep.',
#  u'Costa Rica',
#  u"Cote d'Ivoire",
#  u'Djibouti',
#  u'Dominica',
#  u'Dominican Republic',
#  u'Ecuador',
#  u'Egypt, Arab Rep.',
#  u'El Salvador',
#  u'Eritrea',
#  u'Ethiopia',
#  u'Fiji',
#  u'Gabon',
#  u'Gambia, The',
#  u'Georgia',
#  u'Ghana',
#  u'Grenada',
#  u'Guatemala',
#  u'Guinea',
#  u'Guinea-Bissau',
#  u'Guyana',
#  u'Haiti',
#  u'Honduras',
#  u'India',
#  u'Indonesia',
#  u'Iran, Islamic Rep.',
#  u'Jamaica',
#  u'Jordan',
#  u'Kazakhstan',
#  u'Kenya',
#  u'Kosovo',
#  u'Lao PDR',
#  u'Lebanon',
#  u'Lesotho',
#  u'Liberia',
#  u'Macedonia, FYR',
#  u'Malawi',
#  u'Malaysia',
#  u'Maldives',
#  u'Mali',
#  u'Mauritania',
#  u'Mauritius',
#  u'Moldova',
#  u'Mongolia',
#  u'Montenegro',
#  u'Morocco',
#  u'Mozambique',
#  u'Myanmar',
#  u'Nepal',
#  u'Nicaragua',
#  u'Niger',
#  u'Nigeria',
#  u'Pakistan',
#  u'Panama',
#  u'Papua New Guinea',
#  u'Paraguay',
#  u'Philippines',
#  u'Romania',
#  u'Russian Federation',
#  u'Rwanda',
#  u'Samoa',
#  u'Sao Tome and Principe',
#  u'Senegal',
#  u'Serbia',
#  u'Sierra Leone',
#  u'Solomon Islands',
#  u'Somalia',
#  u'South Africa',
#  u'Sri Lanka',
#  u'St. Lucia',
#  u'St. Vincent and the Grenadines',
#  u'Sudan',
#  u'Swaziland',
#  u'Syrian Arab Republic',
#  u'Tajikistan',
#  u'Tanzania',
#  u'Thailand',
#  u'Togo',
#  u'Tonga',
#  u'Tunisia',
#  u'Turkey',
#  u'Turkmenistan',
#  u'Uganda',
#  u'Ukraine',
#  u'Uzbekistan',
#  u'Vanuatu',
#  u'Venezuela, RB',
#  u'Vietnam',
#  u'Yemen, Rep.',
#  u'Zambia',
#  u'Zimbabwe']

# %%
c_l

# %%
m_l

# %%
d_2016.head()
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND
#
#    Adjusted net enrollment rate, primary (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net enrollment rate, primary, female (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted net enrollment rate, primary, male (% of primary school age children)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school (% of lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school, female (% of female lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adolescents out of school, male (% of male lower secondary school age)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adults (ages 15+) and children (ages 0-14) newly infected with HIV  \
# 0                                             1000.0
# 1                                              500.0
# 2                                             1000.0
# 3                                                NaN
# 4                                                NaN
#
#    Adults (ages 15+) newly infected with HIV  \
# 0                                     1000.0
# 1                                      500.0
# 2                                     1000.0
# 3                                        NaN
# 4                                        NaN
#
#                              ...                             \
# 0                            ...
# 1                            ...
# 2                            ...
# 3                            ...
# 4                            ...
#
#    Wholesale price index (2010 = 100)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife (any of five reasons) (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she argues with him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she burns the food (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she neglects the children (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who believe a husband is justified in beating his wife when she refuses sex with him (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Women's share of population ages 15+ living with HIV (%)
# 0                                          28.627356
# 1                                          29.800597
# 2                                          46.194624
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 1027 columns]

# %%
llave = d_2016.keys()[8]
valores = d_2016[llave] 
t_max = np.nanmax(valores)[0]
valores=valores/t_max

# %%
valores
# Out:
# 0      0.003704
# 1      0.001852
# 2      0.003704
# 3           NaN
# 4           NaN
# 5      0.092593
# 6           NaN
# 8      0.020370
# 9      0.001852
# 10          NaN
# 11     0.004074
# 12          NaN
# 13     0.003704
# 14          NaN
# 15     0.000370
# 16     0.005556
# 17     0.000741
# 18     0.006667
# 19          NaN
# 20     0.001852
# 21     0.013333
# 22          NaN
# 23          NaN
# 24     0.004074
# 25          NaN
# 26     0.037037
# 27     0.177778
# 28          NaN
# 29          NaN
# 30     0.001852
#          ...
# 232    0.003704
# 233         NaN
# 234         NaN
# 235    0.004815
# 236    0.203704
# 237    0.023704
# 238         NaN
# 239    0.015185
# 240         NaN
# 241    0.001852
# 242    0.001852
# 243         NaN
# 244         NaN
# 245         NaN
# 246         NaN
# 247    0.192593
# 248    0.062963
# 249         NaN
# 250         NaN
# 251         NaN
# 253    0.003704
# 254         NaN
# 255         NaN
# 256    0.024074
# 257    0.040741
# 258         NaN
# 259         NaN
# 261    0.004074
# 262    0.218519
# 263    0.148148
# Name: Adults (ages 15+) and children (ages 0-14) newly infected with HIV, Length: 240, dtype: float64

# %%
d_2016_n['Gross capital formation (constant 2010 US$)']
# Out:
# 0           NaN
# 1      0.000390
# 2      0.010280
# 3           NaN
# 4           NaN
# 5           NaN
# 6      0.000033
# 8      0.008286
# 9      0.000252
# 10          NaN
# 11     0.037255
# 12     0.010865
# 13          NaN
# 14     0.000246
# 15          NaN
# 16     0.005406
# 17          NaN
# 18     0.001956
# 19     0.013521
# 20     0.000042
# 21     0.000318
# 22          NaN
# 23     0.000127
# 24     0.000620
# 25          NaN
# 26          NaN
# 27     0.044389
# 28          NaN
# 29     0.000457
# 30     0.001285
#          ...
# 232    0.015446
# 233         NaN
# 234         NaN
# 235         NaN
# 236    0.001382
# 237    0.009306
# 238         NaN
# 239    0.000122
# 240         NaN
# 241    0.000327
# 242         NaN
# 243    0.034718
# 244         NaN
# 245         NaN
# 246         NaN
# 247    0.000791
# 248    0.003025
# 249    0.009357
# 250    0.053317
# 251         NaN
# 253    0.001031
# 254    0.001855
# 255         NaN
# 256         NaN
# 257    0.005921
# 258         NaN
# 259    0.000254
# 261         NaN
# 262         NaN
# 263    0.000244
# Name: Gross capital formation (constant 2010 US$), Length: 240, dtype: float64
