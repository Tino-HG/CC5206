# %% [markdown]
# # Proyecto CC5206
#
# Mineria de datos sobre datasets del banco mundial. Eliminar ultimas filas del excel

# %% [markdown]
# # Importar librerias y dataset

# %%
import numpy as np
import pandas as pd
import pdb

yr = 1981 #IR CAMBIANDO EL AÑO
fname = 'dev_'+str(yr)+'_proc.xlsx'

d_2016 = pd.read_excel(fname, keep_default_na=False, na_values='')

d_2016.head()
# Out:
#           Country Name Country Code  \
# 0          Afghanistan          AFG
# 1              Albania          ALB
# 2              Algeria          DZA
# 5               Angola          AGO
# 6  Antigua and Barbuda          ATG
#
#    Adjusted savings: education expenditure (% of GNI)  \
# 0                                           1.700000
# 1                                           2.800000
# 2                                           4.946261
# 5                                           5.018114
# 6                                           3.200000
#
#    Adjusted savings: mineral depletion (current US$)  \
# 0                                       0.000000e+00
# 1                                       7.230892e+06
# 2                                       4.085131e+06
# 5                                       0.000000e+00
# 6                                       0.000000e+00
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                           154.1398
# 1                                            18.4554
# 2                                            60.1972
# 5                                           232.4580
# 6                                            62.1648
#
#    Age dependency ratio (% of working-age population)  \
# 0                                          94.740816
# 1                                          68.895135
# 2                                          98.486367
# 5                                         101.355064
# 6                                          64.463052
#
#    Age dependency ratio, old (% of working-age population)  \
# 0                                           4.736706
# 1                                           9.002059
# 2                                           6.818327
# 5                                           5.253611
# 6                                           8.911248
#
#    Age dependency ratio, young (% of working-age population)  \
# 0                                          90.004110
# 1                                          59.893077
# 2                                          91.668040
# 5                                          96.101454
# 6                                          55.551804
#
#    Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                           58.286616                    380530.0
# 1                           40.729927                     11160.0
# 2                           16.446380                    391710.0
# 5                           46.041550                    574000.0
# 6                           15.909091                        70.0
#
#                   ...                  Rural population growth (annual %)  \
# 0                 ...                                           -1.774089
# 1                 ...                                            1.606684
# 2                 ...                                            1.518056
# 5                 ...                                            2.795917
# 6                 ...                                           -0.635108
#
#    Secondary education, duration (years)  Surface area (sq. km)  \
# 0                                    6.0               652860.0
# 1                                    8.0                28750.0
# 2                                    7.0              2381740.0
# 5                                    6.0              1246700.0
# 6                                    5.0                  440.0
#
#    Survival to age 65, female (% of cohort)  \
# 0                                  34.59625
# 1                                  81.50489
# 2                                  63.12642
# 5                                  34.48487
# 6                                  73.51973
#
#    Survival to age 65, male (% of cohort)  \
# 0                                30.21416
# 1                                73.63209
# 2                                56.48563
# 5                                28.13642
# 6                                65.98545
#
#    Total fisheries production (metric tons)  \
# 0                                     870.0
# 1                                    9376.0
# 2                                   56000.0
# 5                                  130957.0
# 6                                    1157.0
#
#    Total greenhouse gas emissions (kt of CO2 equivalent)  Urban population  \
# 0                                       15810.335000               2079495
# 1                                       10520.362500                927513
# 2                                       79915.671000               8858976
# 5                                       41894.794960               1876542
# 6                                         430.108984                 25352
#
#    Urban population (% of total)  Urban population growth (annual %)
# 0                         15.930                            0.097090
# 1                         34.024                            2.775926
# 2                         44.420                            5.081803
# 5                         20.299                            6.123244
# 6                         34.698                           -0.283599
#
# [5 rows x 117 columns]

# %% [markdown]
# # Eliminar Outliers

# %%
#'''
outliers1 = [u'High income', u'High income: OECD', u'OECD members', u'World']
outliers2 = [u'East Asia & Pacific',u'East Asia & Pacific (excluding high income)',
             u'Euro area',u'Europe & Central Asia',u'European Union',u'Low & middle income',
             u'Middle income',u'North America',u'Upper middle income']

outliers3 = [u'Arab World', u'Sub-Saharan Africa',
             u'Sub-Saharan Africa (excluding high income)', u'Middle East & North Africa',
             u'Middle East & North Africa (excluding high income)', 
             u'Latin America & Caribbean',u'Latin America & Caribbean (excluding high income)',
             u'Least developed countries: UN classification', 
             u'Heavily indebted poor countries (HIPC)',u'High income',u'High income: nonOECD',
             u'High income: OECD', u'Euro area',u'Europe & Central Asia',
             u'Europe & Central Asia (excluding high income)',u'European Union',
             u'East Asia & Pacific',u'East Asia & Pacific (excluding high income)',
             u'Lower middle income',u'South Asia']

outliers4 = [u'IDA & IBRD total', u'IDA blend', u'IDA only', u'IDA total',
            u'East Asia & Pacific (IDA & IBRD countries)',u'Europe & Central Asia (IDA & IBRD countries)',
            u'Fragile and conflict affected situations',u'IBRD only',u'Late-demographic dividend',
            u'Latin America & the Caribbean (IDA & IBRD countries)',
            u'Middle East & North Africa (IDA & IBRD countries)',u'Not classified',
            u'Other small states',u'Post-demographic dividend',u'Pre-demographic dividend']


outliers5 = [u'Early-demographic dividend',u'Early-demographic dividend',u'Central Europe and the Baltics',
            u'South Asia (IDA & IBRD)',u'Sub-Saharan Africa (IDA & IBRD countries)',
            u'Sub-Saharan Africa (IDA & IBRD countries)', u'South Asia (IDA & IBRD)',u'Low income']

for out in outliers1:
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers2:
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers3:
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers4:
    d_2016 = d_2016[d_2016['Country Name'] != out]
for out in outliers5:
    d_2016 = d_2016[d_2016['Country Name'] != out]
#paises = xdata['Country Name'].values.tolist()
paises = d_2016['Country Name'].values.tolist()
#xdata.head()

# %% [markdown]
# # Normalización

# %%
d_2016_n = d_2016
for k in range(2,len(d_2016.keys())):
    
    llave = d_2016.keys()[k]
    valores = d_2016[llave] 
    xvals = valores.tolist()
    #Normalización
    xmax = np.nanmax(valores)#[0]
    xmin = np.nanmin(valores)#[0]
    norm = xmax - xmin
    #pdb.set_trace()
    if (not np.isnan(xmax)) and norm!=0:
            d_2016_n[llave] = (d_2016[llave]-xmin)/norm
    

d_2016_n.head()
# Out:
#           Country Name Country Code  \
# 0          Afghanistan          AFG
# 1              Albania          ALB
# 2              Algeria          DZA
# 5               Angola          AGO
# 6  Antigua and Barbuda          ATG
#
#    Adjusted savings: education expenditure (% of GNI)  \
# 0                                           0.043613
# 1                                           0.091588
# 2                                           0.185193
# 5                                           0.188327
# 6                                           0.109033
#
#    Adjusted savings: mineral depletion (current US$)  \
# 0                                           0.000000
# 1                                           0.002453
# 2                                           0.001386
# 5                                           0.000000
# 6                                           0.000000
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                           0.657006
# 1                                           0.062777
# 2                                           0.245585
# 5                                           1.000000
# 6                                           0.254202
#
#    Age dependency ratio (% of working-age population)  \
# 0                                           0.739004
# 1                                           0.368712
# 2                                           0.792666
# 5                                           0.833766
# 6                                           0.305214
#
#    Age dependency ratio, old (% of working-age population)  \
# 0                                           0.114758
# 1                                           0.293981
# 2                                           0.202224
# 5                                           0.136477
# 6                                           0.290165
#
#    Age dependency ratio, young (% of working-age population)  \
# 0                                           0.791491
# 1                                           0.412652
# 2                                           0.812426
# 5                                           0.868205
# 6                                           0.358033
#
#    Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                            0.675931                    0.078823
# 1                            0.470684                    0.002308
# 2                            0.186796                    0.081139
# 5                            0.532779                    0.118901
# 6                            0.180515                    0.000010
#
#                   ...                  Rural population growth (annual %)  \
# 0                 ...                                            0.526543
# 1                 ...                                            0.676424
# 2                 ...                                            0.672495
# 5                 ...                                            0.729147
# 6                 ...                                            0.577038
#
#    Secondary education, duration (years)  Surface area (sq. km)  \
# 0                                    0.4               0.038182
# 1                                    0.8               0.001680
# 2                                    0.6               0.139296
# 5                                    0.4               0.072913
# 6                                    0.2               0.000025
#
#    Survival to age 65, female (% of cohort)  \
# 0                                  0.103216
# 1                                  0.876069
# 2                                  0.573271
# 5                                  0.101381
# 6                                  0.744508
#
#    Survival to age 65, male (% of cohort)  \
# 0                                0.107505
# 1                                0.886156
# 2                                0.578654
# 5                                0.070243
# 6                                0.749022
#
#    Total fisheries production (metric tons)  \
# 0                                  0.000075
# 1                                  0.000821
# 2                                  0.004908
# 5                                  0.011479
# 6                                  0.000100
#
#    Total greenhouse gas emissions (kt of CO2 equivalent)  Urban population  \
# 0                                           0.002706              0.010311
# 1                                           0.001799              0.004549
# 2                                           0.013702              0.044220
# 5                                           0.007180              0.009296
# 6                                           0.000068              0.000037
#
#    Urban population (% of total)  Urban population growth (annual %)
# 0                       0.119658                            0.058328
# 1                       0.309130                            0.155371
# 2                       0.417992                            0.238903
# 5                       0.165408                            0.276630
# 6                       0.316188                            0.044538
#
# [5 rows x 117 columns]

# %% [markdown]
# # Analisis Estadistico

# %%
varianzas = []
promedios = []
maximos = []
minimos = []
desv = []
for k in range(2,len(d_2016_n.keys())):
    
    llave = d_2016_n.keys()[k]
    valores = d_2016_n[llave] 
    count = 0
    
    #Normalización
    xmax = np.nanmax(valores)
    xmean = np.nanmean(valores)
    xmin = np.nanmin(valores)
    xstd = np.nanstd(valores)
    xvar = np.nanvar(valores)
    if np.isnan(xvar):
        print llave
    
    promedios.append(xmean)
    minimos.append(xmin)
    maximos.append(xmax)
    desv.append(xstd)
    varianzas.append(xvar)
    
sort = np.sort(varianzas)

most = -1   

print "Estadisticas con mayor varianza:"
#pdb.set_trace()
for i in range(10):
    value = sort[most]
    j = np.argwhere(varianzas == sort[most])+2
    features = d_2016_n.keys()
    print str(i+1)+' '+str(features[j])+' ('+str(sort[most]) +')'
    most-=1
# Out:
# Estadisticas con mayor varianza:
# 1 Index([[u'Preprimary education, duration (years)']], dtype='object') (0.0850610540765)
# 2 Index([[u'Population ages 0-14, female (% of total)']], dtype='object') (0.0833385859679)
# 3 Index([[u'Population ages 0-14 (% of total)']], dtype='object') (0.0830665357049)
# 4 Index([[u'Population ages 0-4, female (% of female population)']], dtype='object') (0.0821655348991)
# 5 Index([[u'Population ages 0-14, male (% of total)']], dtype='object') (0.0800540861958)
# 6 Index([[u'Age dependency ratio, young (% of working-age population)']], dtype='object') (0.0795401340248)
# 7 Index([[u'Fertility rate, total (births per woman)']], dtype='object') (0.0754996661788)
# 8 Index([[u'Population ages 0-4, male (% of male population)']], dtype='object') (0.0743771676163)
# 9 Index([[u'Birth rate, crude (per 1,000 people)']], dtype='object') (0.073089182652)
# 10 Index([[u'Population ages 15-64 (% of total)']], dtype='object') (0.0728400197542)

# %% [markdown]
# # Graficos

# %% [markdown]
# ## Histogramas

# %%
'''
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

x = []
for nonan in xdata['Population ages 0-14, total']:
#for nonan in xdata['Self-employed, male (% of males employed)']:
    if not np.isnan(nonan):
        x.append(nonan)

ax1.hist(x, 5, facecolor='green', alpha=0.75)

ax1.set_xlabel('Population ages 0-14')
ax1.set_ylabel('Total')
#ax1.title('Histograma')

#plt.add_subplot(212, facecolor='r')
x =[]
for nonan in xdata['Self-employed, male (% of males employed)']:
    if not np.isnan(nonan):
        x.append(nonan)

ax2.hist(x, 5, facecolor='blue', alpha=0.75)

ax2.set_xlabel('Self-employed, male')
ax2.set_ylabel('% of males employed')

plt.show()
'''
# Out:
# "\nimport matplotlib.pyplot as plt\n\nfig = plt.figure(figsize=(10,4))\nax1 = fig.add_subplot(1, 2, 1)\nax2 = fig.add_subplot(1, 2, 2)\n\nx = []\nfor nonan in xdata['Population ages 0-14, total']:\n#for nonan in xdata['Self-employed, male (% of males employed)']:\n    if not np.isnan(nonan):\n        x.append(nonan)\n\nax1.hist(x, 5, facecolor='green', alpha=0.75)\n\nax1.set_xlabel('Population ages 0-14')\nax1.set_ylabel('Total')\n#ax1.title('Histograma')\n\n#plt.add_subplot(212, facecolor='r')\nx =[]\nfor nonan in xdata['Self-employed, male (% of males employed)']:\n    if not np.isnan(nonan):\n        x.append(nonan)\n\nax2.hist(x, 5, facecolor='blue', alpha=0.75)\n\nax2.set_xlabel('Self-employed, male')\nax2.set_ylabel('% of males employed')\n\nplt.show()\n"

# %% [markdown]
# ## Codo

# %%
np_df = d_2016_n.as_matrix()
test = np_df[:,2:]
for row in range(test.shape[0]):
    for column in range(test.shape[1]):
        val = test[row][column]
        #print val
        if np.isnan(val):
            test[row][column]= promedios[column] 
        else:
            #test[row][column]= val/maximos[column] 
            pass

xdf = pd.DataFrame(test)

vectors = []
tot = test#.T
for i in range(len(tot[:,0])):
    vectors.append(tot[i])
    

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets
from sklearn import metrics
from scipy.spatial.distance import cdist

X = tot

# k means determine k
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
 
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# # TSNE

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
X = vectors
X_embedded = TSNE(n_components=2,n_iter=100000000).fit_transform(X)
X_embedded.shape
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c="r", cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# # PCA

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]

X = tot
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X = pca.transform(X)


plt.scatter(X[:, 0], X[:, 1], c="r", cmap=plt.cm.spectral,
           edgecolor='k')


plt.show()

# %% [markdown]
# # clustering

# %%
from sklearn.cluster import KMeans
from sklearn import datasets

X = tot

kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
labels = kmeans.labels_

centroids = kmeans.cluster_centers_

# %% [markdown]
# # tSNE

# %%
# %matplotlib inline

r = []
r_l = []
g = []
g_l = []
b = [] 
b_l = []
y = []
y_l = []
c=[]
c_l=[]
m=[]
m_l=[]

plt.gcf().clear()
r_embedded = TSNE(n_components=2,n_iter=100000000).fit_transform(X)
r_embedded.shape
for k in range(len(labels)):
    if labels[k]==0:
        r.append(X_embedded[k])
        r_l.append(paises[k])
    elif labels[k]==1:
        g.append(X_embedded[k])
        g_l.append(paises[k])
    elif labels[k]==2:
        b.append(X_embedded[k])
        b_l.append(paises[k])
    elif labels[k]==3:
        y.append(X_embedded[k])
        y_l.append(paises[k])
    elif labels[k]==4:
        c.append(X_embedded[k])
        c_l.append(paises[k])
    elif labels[k]==5:
        m.append(X_embedded[k])
        m_l.append(paises[k])
plt.scatter([item[0] for item in r], [item[1] for item in r], c="r", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in g], [item[1] for item in g], c="g", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in b], [item[1] for item in b], c="b", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in y], [item[1] for item in y], c="y", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in c], [item[1] for item in c], c="c", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in m], [item[1] for item in m], c="m", cmap=plt.cm.Spectral)
#plt.show()
tsnename='k3_dev_'+str(yr)+'_tsne'
plt.savefig(tsnename)
plt.gcf().clear()

# %% [markdown]
# # PCA

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets


X = tot
pca = decomposition.PCA(n_components=2)
pca.fit(X)
X = pca.transform(X)

r = []
r_l = []
g = []
g_l = []
b = [] 
b_l = []
y = []
y_l = []
c = []
c_l = []

for k in range(len(labels)):
    if labels[k]==0:
        r.append(X[k])
        r_l.append(paises[k])
    elif labels[k]==1:
        g.append(X[k])
        g_l.append(paises[k])
    elif labels[k]==2:
        b.append(X[k])
        b_l.append(paises[k])
    elif labels[k]==3:
        y.append(X[k])
        y_l.append(paises[k])
    elif labels[k]==4:
        c.append(X[k])
        c_l.append(paises[k])
        
plt.scatter([item[0] for item in r], [item[1] for item in r], c="r", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in g], [item[1] for item in g], c="g", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in b], [item[1] for item in b], c="b", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in y], [item[1] for item in y], c="y", cmap=plt.cm.Spectral)
plt.scatter([item[0] for item in c], [item[1] for item in c], c="c", cmap=plt.cm.Spectral)
#plt.show()
pcaname='k3_dev_'+str(yr)+'_pca'
plt.savefig(pcaname)
plt.gcf().clear()

# %%
r_l
# Out:
# [u'Argentina',
#  u'Aruba',
#  u'Australia',
#  u'Austria',
#  u'Barbados',
#  u'Belarus',
#  u'Belgium',
#  u'Bosnia and Herzegovina',
#  u'Bulgaria',
#  u'Canada',
#  u'Croatia',
#  u'Cyprus',
#  u'Czech Republic',
#  u'Denmark',
#  u'Estonia',
#  u'Finland',
#  u'France',
#  u'Georgia',
#  u'Germany',
#  u'Greece',
#  u'Hong Kong SAR, China',
#  u'Hungary',
#  u'Iceland',
#  u'Ireland',
#  u'Israel',
#  u'Italy',
#  u'Japan',
#  u'Latvia',
#  u'Lithuania',
#  u'Luxembourg',
#  u'Macao SAR, China',
#  u'Macedonia, FYR',
#  u'Malta',
#  u'Moldova',
#  u'Netherlands',
#  u'New Zealand',
#  u'Norway',
#  u'Poland',
#  u'Portugal',
#  u'Puerto Rico',
#  u'Romania',
#  u'Russian Federation',
#  u'Slovak Republic',
#  u'Slovenia',
#  u'Spain',
#  u'Sweden',
#  u'Switzerland',
#  u'Ukraine',
#  u'United Kingdom',
#  u'United States',
#  u'Uruguay']

# %%
g_l
# Out:
# [u'Afghanistan',
#  u'Algeria',
#  u'Angola',
#  u'Bangladesh',
#  u'Belize',
#  u'Benin',
#  u'Bhutan',
#  u'Bolivia',
#  u'Botswana',
#  u'Burkina Faso',
#  u'Burundi',
#  u'Cabo Verde',
#  u'Cambodia',
#  u'Cameroon',
#  u'Central African Republic',
#  u'Chad',
#  u'Comoros',
#  u'Congo, Dem. Rep.',
#  u'Congo, Rep.',
#  u"Cote d'Ivoire",
#  u'Djibouti',
#  u'El Salvador',
#  u'Equatorial Guinea',
#  u'Eritrea',
#  u'Ethiopia',
#  u'Gambia, The',
#  u'Ghana',
#  u'Guatemala',
#  u'Guinea',
#  u'Guinea-Bissau',
#  u'Haiti',
#  u'Honduras',
#  u'Iran, Islamic Rep.',
#  u'Iraq',
#  u'Jordan',
#  u'Kenya',
#  u'Lao PDR',
#  u'Lesotho',
#  u'Liberia',
#  u'Libya',
#  u'Madagascar',
#  u'Malawi',
#  u'Maldives',
#  u'Mali',
#  u'Mauritania',
#  u'Micronesia, Fed. Sts.',
#  u'Mongolia',
#  u'Morocco',
#  u'Mozambique',
#  u'Myanmar',
#  u'Namibia',
#  u'Nepal',
#  u'Nicaragua',
#  u'Niger',
#  u'Nigeria',
#  u'Oman',
#  u'Pacific island small states',
#  u'Pakistan',
#  u'Papua New Guinea',
#  u'Rwanda',
#  u'Samoa',
#  u'Sao Tome and Principe',
#  u'Senegal',
#  u'Sierra Leone',
#  u'Solomon Islands',
#  u'Somalia',
#  u'Sudan',
#  u'Swaziland',
#  u'Syrian Arab Republic',
#  u'Tanzania',
#  u'Timor-Leste',
#  u'Togo',
#  u'Uganda',
#  u'Vanuatu',
#  u'Yemen, Rep.',
#  u'Zambia',
#  u'Zimbabwe']

# %%
b_l
# Out:
# [u'Albania',
#  u'Antigua and Barbuda',
#  u'Armenia',
#  u'Azerbaijan',
#  u'Bahamas, The',
#  u'Bahrain',
#  u'Brazil',
#  u'Brunei Darussalam',
#  u'Caribbean small states',
#  u'Chile',
#  u'China',
#  u'Colombia',
#  u'Costa Rica',
#  u'Cuba',
#  u'Dominican Republic',
#  u'Ecuador',
#  u'Egypt, Arab Rep.',
#  u'Fiji',
#  u'French Polynesia',
#  u'Gabon',
#  u'Grenada',
#  u'Guam',
#  u'Guyana',
#  u'India',
#  u'Indonesia',
#  u'Jamaica',
#  u'Kazakhstan',
#  u'Kiribati',
#  u'Korea, Dem. People\u2019s Rep.',
#  u'Korea, Rep.',
#  u'Kuwait',
#  u'Kyrgyz Republic',
#  u'Lebanon',
#  u'Malaysia',
#  u'Mauritius',
#  u'Mexico',
#  u'New Caledonia',
#  u'Panama',
#  u'Paraguay',
#  u'Peru',
#  u'Philippines',
#  u'Qatar',
#  u'Saudi Arabia',
#  u'Seychelles',
#  u'Singapore',
#  u'Small states',
#  u'South Africa',
#  u'Sri Lanka',
#  u'St. Lucia',
#  u'St. Vincent and the Grenadines',
#  u'Suriname',
#  u'Tajikistan',
#  u'Thailand',
#  u'Tonga',
#  u'Trinidad and Tobago',
#  u'Tunisia',
#  u'Turkey',
#  u'Turkmenistan',
#  u'United Arab Emirates',
#  u'Uzbekistan',
#  u'Venezuela, RB',
#  u'Vietnam',
#  u'Virgin Islands (U.S.)']

# %%
y_l
# Out:
# []

# %%
c_l
# Out:
# []

# %%
m_l
# Out:
# []

# %% [markdown]
# ## Exportar Etiquetas

# %%
clusters = [r,g,b,y,c,m]
clusters_l = [r_l,g_l,b_l,y_l,c_l,m_l]
ncluster = 1
pre_out = []#('Country','Label')]
for cluster_l in clusters_l:
    for country in cluster_l:
        pre_out.append((country,ncluster))
    ncluster +=1

out = pd.DataFrame(pre_out,columns=['Country', 'Label'])
out.head()
labelname='Labels'+str(yr)+'.xlsx'
writer = pd.ExcelWriter(labelname)
out.to_excel(writer,'Data')
writer.save()
